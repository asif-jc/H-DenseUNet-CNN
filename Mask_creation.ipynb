# %% [markdown]
# Environment and Libraries

# %%
#Libraries
import cv2
import os
import glob
import warnings
import scipy.misc
import numpy as np
import python_utilities
import python_utils
import labelme
import nibabel as nib
import torch
import transform
# # import nibabel as nib
import SimpleITK as sitk
from scipy import ndimage
import matplotlib.pyplot as plt
import skimage
# os.environ['PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION'] = 'python'
from matplotlib.widgets import Slider
import pydicom
import trimesh
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon

# import keras.api._v2.keras as keras
import tensorflow as tf
from tensorflow import keras
# from tensorflow.keras import layers
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Concatenate, BatchNormalization, Activation, Conv2DTranspose, concatenate, Dropout
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from keras.models import Model

from scipy.spatial.distance import directed_hausdorff

from keras.callbacks import ModelCheckpoint
# Out:
# /Users/pranavrao/opt/anaconda3/lib/python3.9/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# Preprocessing Data

# %%
from preprocessing import preprocessing
import numpy as np
print('-'*30)
print('Loading and preprocessing training data...')
print('-'*30)


total_slices_raw_data = 1015
DataOnlyAOI = False
scans_path = '/Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/MRI Scans - Tairawhiti'
segmasks_fnames = ['1_R_tibia_15A']
scan_data_folders = ['15A_AutoBind_WaterWATER_450']

imgs_train, imgs_mask_train = preprocessing(scans_path, segmasks_fnames, scan_data_folders, total_slices_raw_data, DataOnlyAOI)

if (DataOnlyAOI == False):
    imgs_train = np.reshape(imgs_train, (len(scan_data_folders) * total_slices_raw_data, 512, 512))
    imgs_mask_train = np.reshape(imgs_mask_train, (len(segmasks_fnames) * total_slices_raw_data, 512, 512))
    imgs_train = np.expand_dims(imgs_train, axis=-1)
    imgs_mask_train = np.expand_dims(imgs_mask_train, axis=-1)

if (DataOnlyAOI == True):
    imgs_train = np.expand_dims(imgs_train, axis=-1)
    imgs_mask_train = np.expand_dims(imgs_mask_train, axis=-1)

print("\n")
print('Final Training Image Input Shape: ', imgs_train.shape)
print('Final Training Mask Input Shape: ', imgs_mask_train.shape)

print('-'*30)
print('Completed Preprocessing Stage!')
print('-'*30)
# Out:
# /Users/pranavrao/opt/anaconda3/lib/python3.9/site-packages/pyntcloud/utils/numba.py:5: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def groupby_count(xyz, indices, out):
# /Users/pranavrao/opt/anaconda3/lib/python3.9/site-packages/pyntcloud/utils/numba.py:12: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def groupby_sum(xyz, indices, N, out):
# /Users/pranavrao/opt/anaconda3/lib/python3.9/site-packages/pyntcloud/utils/numba.py:19: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def groupby_max(xyz, indices, N, out):
# ------------------------------
# Loading and preprocessing training data...
# ------------------------------
# Patient Scan Data Folders Included in Run:  ['15A_AutoBind_WaterWATER_450']
#
#
# Segmentation Mask:  1_R_tibia_15A
# Patient Scan Data:  15A_AutoBind_WaterWATER_450
# Height of Paitent in mm:  1523.5
# Length of Paitent AOI (tibia) in mm:  315.1292724609375
# AOI Slice Start:  684
# AOI Slice End:  893
# AOI Slice Range:  210
# Mask Slices Normalized to MRI Scans Shape (Purely AOI):  (210, 512, 512)
#
#
# Masks Binarised
# Number of Paitents:  1
# Training Scans Input Shape:  (1, 1015, 512, 512)
# Training Masks Input Shape:  (1, 1015, 512, 512)
# Memory usage of training_scans: 1015 MB.
# Memory usage of train_mask_tibia_labels: 2030 MB.
#
#
# Final Training Image Input Shape:  (1015, 512, 512, 1)
# Final Training Mask Input Shape:  (1015, 512, 512, 1)
# ------------------------------
# Completed Preprocessing Stage!
# ------------------------------

# %%
from preprocessing import read_dicom_files
from preprocessing import flatten_2d_array
from preprocessing import preprocessing
from matplotlib.patches import Polygon
import matplotlib.path as mpath

dicom_path = "/Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/MRI Scans - Tairawhiti/12A_AutoBindWATER_450"
ply_path = '/Users/pranavrao/Documents/GitHub/Part4Project/SegmentationMasks/8_R_tibia_12A.ply'


seg_masks_15A_tibia = sitk.ReadImage('/Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/Mask_exports/8_R_tibia_12A.nii')
seg_masks_15A_tibia_data = sitk.GetArrayFromImage(seg_masks_15A_tibia)
seg_masks_15A_tibia_data = seg_masks_15A_tibia_data[::-1, :, :]


def superimpose_images(image1, image2):
    image1 = image1 / np.max(image1)
    image2 = image2 / np.max(image2)
    alpha = 0.5
    superimposed_image = alpha * image1 + (1 - alpha) * image2
    return superimposed_image

slice = 815


image1 = imgs_train[slice, :, :]
image2 = np.expand_dims(seg_masks_15A_tibia_data[slice,:,:], axis=-1)
superimposed_image = superimpose_images(image1, image2)

plt.imshow(superimposed_image, cmap='gray')
plt.title('Superimposed')
plt.axis('on')
plt.show()

# %%
def visualize_dicom_and_masks(dicom_image, masks):
    num_slices = dicom_image.shape[0]

    # Plot DICOM images and corresponding masks side by side
    fig, axes = plt.subplots(nrows=num_slices, ncols=2, figsize=(10, 5 * num_slices))
    
    for i in range(num_slices):
        # Plot DICOM image
        axes[i, 0].imshow(dicom_image[i], cmap='gray')
        axes[i, 0].set_title(f"DICOM Slice {i}")
        axes[i, 0].axis('off')

        # Plot mask
        axes[i, 1].imshow(masks[i], cmap='gray')
        axes[i, 1].set_title(f"Mask Slice {i}")
        axes[i, 1].axis('off')

    plt.tight_layout()
    plt.show()


visualize_dicom_and_masks(dicom_image, masks)

# %% [markdown]
# Exporting out Labelled Datasets

# %%
# Exporting Training Scan and Mask Data
from writeout_dataset import WriteOutTextFile
from writeout_dataset import WriteOutImagePNGFiles

starting_slice = 1
save_directory_data_txt = '/Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia'
save_directory_data_img = '/Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/img/Data'
save_directory_mask_txt = '/Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia'
save_directory_mask_img = '/Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/img/Masks'

WriteOutTextFile(imgs_train[:, :, :, 0], save_directory_data_txt, starting_slice)   
# WriteOutImagePNGFiles(imgs_train, save_directory_data_img)

WriteOutTextFile(imgs_mask_train[:, :, :, 0], save_directory_mask_txt, starting_slice)   
# WriteOutImagePNGFiles(imgs_mask_train, save_directory_mask_img)
# Out:
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_1.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_2.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_3.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_4.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_5.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_6.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_7.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_8.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_9.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_10.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_11.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_12.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_13.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_14.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_15.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_16.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_17.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_18.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_19.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_20.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_21.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_22.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_23.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_24.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_25.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_26.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_27.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_28.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_29.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_30.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_31.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_32.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_33.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_34.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_35.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_36.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_37.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_38.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_39.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_40.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_41.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_42.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_43.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_44.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_45.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_46.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_47.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_48.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_49.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_50.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_51.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_52.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_53.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_54.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_55.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_56.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_57.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_58.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_59.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_60.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_61.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_62.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_63.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_64.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_65.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_66.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_67.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_68.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_69.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_70.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_71.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_72.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_73.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_74.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_75.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_76.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_77.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_78.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_79.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_80.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_81.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_82.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_83.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_84.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_85.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_86.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_87.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_88.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_89.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_90.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_91.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_92.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_93.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_94.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_95.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_96.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_97.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_98.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_99.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_100.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_101.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_102.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_103.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_104.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_105.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_106.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_107.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_108.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_109.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_110.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_111.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_112.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_113.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_114.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_115.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_116.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_117.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_118.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_119.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_120.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_121.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_122.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_123.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_124.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_125.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_126.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_127.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_128.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_129.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_130.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_131.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_132.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_133.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_134.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_135.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_136.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_137.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_138.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_139.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_140.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_141.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_142.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_143.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_144.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_145.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_146.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_147.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_148.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_149.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_150.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_151.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_152.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_153.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_154.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_155.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_156.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_157.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_158.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_159.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_160.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_161.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_162.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_163.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_164.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_165.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_166.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_167.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_168.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_169.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_170.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_171.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_172.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_173.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_174.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_175.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_176.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_177.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_178.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_179.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_180.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_181.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_182.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_183.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_184.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_185.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_186.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_187.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_188.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_189.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_190.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_191.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_192.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_193.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_194.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_195.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_196.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_197.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_198.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_199.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_200.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_201.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_202.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_203.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_204.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_205.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_206.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_207.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_208.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_209.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_210.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_211.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_212.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_213.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_214.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_215.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_216.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_217.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_218.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_219.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_220.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_221.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_222.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_223.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_224.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_225.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_226.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_227.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_228.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_229.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_230.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_231.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_232.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_233.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_234.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_235.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_236.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_237.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_238.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_239.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_240.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_241.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_242.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_243.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_244.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_245.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_246.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_247.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_248.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_249.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_250.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_251.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_252.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_253.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_254.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_255.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_256.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_257.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_258.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_259.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_260.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_261.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_262.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_263.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_264.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_265.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_266.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_267.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_268.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_269.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_270.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_271.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_272.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_273.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_274.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_275.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_276.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_277.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_278.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_279.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_280.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_281.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_282.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_283.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_284.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_285.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_286.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_287.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_288.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_289.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_290.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_291.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_292.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_293.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_294.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_295.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_296.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_297.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_298.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_299.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_300.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_301.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_302.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_303.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_304.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_305.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_306.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_307.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_308.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_309.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_310.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_311.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_312.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_313.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_314.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_315.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_316.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_317.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_318.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_319.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_320.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_321.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_322.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_323.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_324.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_325.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_326.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_327.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_328.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_329.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_330.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_331.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_332.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_333.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_334.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_335.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_336.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_337.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_338.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_339.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_340.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_341.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_342.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_343.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_344.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_345.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_346.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_347.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_348.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_349.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_350.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_351.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_352.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_353.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_354.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_355.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_356.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_357.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_358.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_359.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_360.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_361.txt
# ...
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_320.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_321.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_322.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_323.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_324.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_325.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_326.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_327.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_328.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_329.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_330.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_331.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_332.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_333.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_334.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_335.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_336.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_337.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_338.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_339.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_340.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_341.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_342.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_343.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_344.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_345.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_346.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_347.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_348.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_349.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_350.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_351.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_352.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_353.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_354.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_355.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_356.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_357.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_358.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_359.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_360.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_361.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_362.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_363.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_364.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_365.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_366.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_367.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_368.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_369.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_370.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_371.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_372.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_373.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_374.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_375.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_376.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_377.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_378.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_379.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_380.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_381.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_382.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_383.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_384.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_385.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_386.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_387.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_388.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_389.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_390.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_391.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_392.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_393.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_394.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_395.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_396.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_397.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_398.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_399.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_400.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_401.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_402.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_403.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_404.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_405.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_406.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_407.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_408.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_409.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_410.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_411.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_412.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_413.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_414.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_415.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_416.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_417.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_418.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_419.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_420.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_421.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_422.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_423.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_424.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_425.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_426.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_427.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_428.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_429.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_430.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_431.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_432.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_433.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_434.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_435.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_436.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_437.txt
# Saved /Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_438.txt

# %% [markdown]
# Data Validation (Visual Sanity Check)

# %%
# Visualiser Tool Scan
temp = np.squeeze(imgs_train)
fig, ax = plt.subplots()
current_slice = 100
img = ax.imshow(temp[current_slice], cmap='gray')
ax.axis('off')

# Configure the slider
ax_slider = plt.axes([0.2, 0.02, 0.6, 0.03])
slider = Slider(ax_slider, 'Slice', 0, temp.shape[0] - 1, valinit=current_slice, valstep=1)

def update_slice(val):
    current_slice = int(slider.val)
    img.set_data(temp[current_slice])
    fig.canvas.draw_idle()

slider.on_changed(update_slice)

plt.show()

# Visualiser Tool Mask
# temp = np.squeeze(imgs_mask_train)
fig, ax = plt.subplots()
current_slice = 100
img = ax.imshow(temp[current_slice], cmap='gray')
ax.axis('off')

# Configure the slider
ax_slider = plt.axes([0.2, 0.02, 0.6, 0.03])
slider = Slider(ax_slider, 'Slice', 0, temp.shape[0] - 1, valinit=current_slice, valstep=1)

def update_slice(val):
    current_slice = int(slider.val)
    img.set_data(temp[current_slice])
    fig.canvas.draw_idle()

slider.on_changed(update_slice)

plt.show()

# %%
temp = np.loadtxt("/Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia/data_100.txt", delimiter=',')
# Visualiser Tool Data Files

fig, ax = plt.subplots()
current_slice = 150
img = ax.imshow(temp, cmap='gray')
ax.axis('off')

# Configure the slider
ax_slider = plt.axes([0.2, 0.02, 0.6, 0.03])
slider = Slider(ax_slider, 'Slice', 0, current_slice, valinit=current_slice, valstep=1)

def update_slice(val):
    current_slice = int(slider.val)
    img.set_data(temp[current_slice])
    fig.canvas.draw_idle()

slider.on_changed(update_slice)

plt.show()

temp = np.loadtxt("/Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia/data_100.txt", delimiter=',')
# Visualiser Tool Data Files

fig, ax = plt.subplots()
current_slice = 150
img = ax.imshow(temp, cmap='gray')
ax.axis('off')

# Configure the slider
ax_slider = plt.axes([0.2, 0.02, 0.6, 0.03])
slider = Slider(ax_slider, 'Slice', 0, current_slice, valinit=current_slice, valstep=1)

def update_slice(val):
    current_slice = int(slider.val)
    img.set_data(temp[current_slice])
    fig.canvas.draw_idle()

slider.on_changed(update_slice)

plt.show()

# %% [markdown]
# 2DUNet Model

# %%
# Define U-Net model
def unet_model(input_shape):
    inputs = Input(input_shape)

    # Encoder
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(inputs)
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(128, 3, activation='relu', padding='same')(pool1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(256, 3, activation='relu', padding='same')(pool2)
    conv3 = Conv2D(256, 3, activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(512, 3, activation='relu', padding='same')(pool3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same')(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    # Bottleneck
    conv5 = Conv2D(1024, 3, activation='relu', padding='same')(pool4)
    conv5 = Conv2D(1024, 3, activation='relu', padding='same')(conv5)
    drop5 = Dropout(0.5)(conv5)

    # Decoder
    up6 = Conv2D(512, 2, activation='relu', padding='same')(UpSampling2D(size=(2, 2))(drop5))
    merge6 = concatenate([drop4, up6], axis=3)
    conv6 = Conv2D(512, 3, activation='relu', padding='same')(merge6)
    conv6 = Conv2D(512, 3, activation='relu', padding='same')(conv6)

    up7 = Conv2D(256, 2, activation='relu', padding='same')(UpSampling2D(size=(2, 2))(conv6))
    merge7 = concatenate([conv3, up7], axis=3)
    conv7 = Conv2D(256, 3, activation='relu', padding='same')(merge7)
    conv7 = Conv2D(256, 3, activation='relu', padding='same')(conv7)

    up8 = Conv2D(128, 2, activation='relu', padding='same')(UpSampling2D(size=(2, 2))(conv7))
    merge8 = concatenate([conv2, up8], axis=3)
    conv8 = Conv2D(128, 3, activation='relu', padding='same')(merge8)
    conv8 = Conv2D(128, 3, activation='relu', padding='same')(conv8)

    up9 = Conv2D(64, 2, activation='relu', padding='same')(UpSampling2D(size=(2, 2))(conv8))
    merge9 = concatenate([conv1, up9], axis=3)
    conv9 = Conv2D(64, 3, activation='relu', padding='same')(merge9)
    conv9 = Conv2D(64, 3, activation='relu', padding='same')(conv9)

    outputs = Conv2D(1, 1, activation='sigmoid')(conv9)

    model = Model(inputs=inputs, outputs=outputs)

    return model

# %%
from writeout_dataset import ReadInDatasets
imgs_train = ReadInDatasets('/Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Data_Tibia')
imgs_mask_train = ReadInDatasets('/Users/pranavrao/Library/CloudStorage/OneDrive-TheUniversityofAuckland/Part4Project/P4P Model Data/txt/Masks_Tibia')
# imgs_mask_train = np.expand_dims(imgs_mask_train, axis=-1)
# imgs_train = np.expand_dims(imgs_train, axis=-1)

# %%
#from writeout_dataset import ReadInDatasets
#imgs_train = ReadInDatasets('D:/P4P Model Data/txt/Data_Tibia')
#imgs_mask_train = ReadInDatasets('D:/P4P Model Data/txt/Masks_Tibia')
imgs_mask_train = np.expand_dims(imgs_mask_train, axis=-1)
imgs_train = np.expand_dims(imgs_train, axis=-1)

# Image Parameters
IMAGE_WDITH = 512
IMAGE_HEIGHT = 512
IMAGE_CHANNELS = 1

# Training, Testing and Validation Parameters
# TRAINING_VOLUMES = [0, 1, 2, 3, 4, 5, 6, 7, 8]
# VALIDATION_VOLUMES = [9]

# Hyperparameters
N_CLASSES = 2
N_INPUT_CHANNELS = 1
# PATCH_SIZE = (32, 32)
# PATCH_STRIDE = (32, 32)

# # Data Preparation Parameters
# CONTENT_THRESHOLD = 0.3 # To Get Rid of Useless Information in the Image

# Training Parameters
N_EPOCHS = 200
BATCH_SIZE = 32
PATIENCE = 3
MODEL_FNAME_PATTERN = 'model.h5'
OPTIMISER = 'Adam'
# LOSS = 'categorical_crossentropy'
LOSS = 'binary_crossentropy'
dropout_rate = 0.40


print('-'*30)
print('Loading and preprocessing train data...')
print('-'*30)

images_train, images_val, labels_train, labels_val = train_test_split(imgs_train, imgs_mask_train, test_size=0.2, random_state=0)
print('Training Image Input Shape: ', images_train.shape)
print('Training Mask Input Shape: ', labels_train.shape)
print('Validation Image Input Shape: ', images_val.shape)
print('Validation Mask Input Shape: ', labels_val.shape)


print('-'*30)
print('Creating and compiling model...')
print('-'*30)

# my_callbacks = [
#     tf.keras.callbacks.EarlyStopping(patience=PATIENCE), # early stopping
#     tf.keras.callbacks.ModelCheckpoint(filepath=MODEL_FNAME_PATTERN, save_best_only=True) # save the best based on validation
# ]

# unet = get_unet()
# unet.compile(optimizer=OPTIMISER, loss=LOSS)
# unet.fit(
#     x=images_train, 
#     y=labels_train,
#     validation_data=(images_val, labels_val),
#     batch_size=BATCH_SIZE,
#     epochs=N_EPOCHS,
#     callbacks=my_callbacks,
#     verbose=1)

# unet.summary()

# unet = get_unet()
# unet.compile(optimizer=OPTIMISER, loss=LOSS)
# unet.load_weights('model.h5')

# testing_scans_processed = images_train[0]
# testing_masks_processed = labels_train[0]
# testing_scans_processed = np.reshape(testing_scans_processed, (1, 512, 512, 1))
# testing_masks_processed = np.reshape(testing_masks_processed, (1, 512, 512, 1))

# # testing_labels_processed = tf.keras.utils.to_categorical(testing_masks_processed, num_classes=2, dtype='float32')

# print('Testing Image Input Shape: ',testing_scans_processed.shape)
# print('Testing Mask Input Shape:',testing_masks_processed.shape)

# prediction = unet.predict(x=testing_scans_processed)
# # prediction = np.argmax(prediction, axis=3)
# # prediction = np.reshape(prediction[0], (512, 512))

# # plt.imshow(prediction, cmap='gray')
# # plt.show()
# Out:
# ------------------------------
# Loading and preprocessing train data...
# ------------------------------
# Training Image Input Shape:  (700, 512, 512, 1)
# Training Mask Input Shape:  (700, 512, 512, 1)
# Validation Image Input Shape:  (176, 512, 512, 1)
# Validation Mask Input Shape:  (176, 512, 512, 1)
# ------------------------------
# Creating and compiling model...
# ------------------------------

# %%
input_shape = (512,512,1)
model = unet_model(input_shape)
model.compile(optimizer='adam', loss='binary_crossentropy')
# model.compile(optimizer='adam', loss=dice_loss)
checkpoint = ModelCheckpoint('model(loss=binary,batch_size=4,epochs=20,train_size=500,aoi=tibia).h5', monitor='val_loss', save_best_only=True, mode='min')
model.fit(x=images_train, y=labels_train, batch_size=4, epochs=20, validation_data=(images_val, labels_val), callbacks=[checkpoint])
model.summary()
# Out:
# Epoch 1/20
# 2023-07-17 16:44:33.455609: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
#   9/175 [>.............................] - ETA: 51:51 - loss: 0.3814
#  10/175 [>.............................] - ETA: 52:10 - loss: 0.3434

# %%
model = 'best_model.h5'
# model = 'model(loss=binary,batch_size=4,epochs=20,train_size=500,aoi=tibia).h5'

from writeout_dataset import ReadInDatasets
imgs_test = ReadInDatasets('/content/drive/MyDrive/Colab Notebooks/Test_Data_Tibia(Collab Sample)', 0, 13)
testing_scans_processed = np.reshape(imgs_test, (len(imgs_test), 512, 512, 1))
print('testing_masks_processed size: ', testing_scans_processed.shape)

def superimpose_images(image1, image2):
    # Normalize the image intensities
    image1 = image1 / np.max(image1)
    image2 = image2 / np.max(image2)

    alpha = 0.5  # Opacity of raw scan
    superimposed_image = alpha * image1 + (1 - alpha) * image2
    return superimposed_image

def dice_coefficient(y_true, y_pred):
    intersection = np.sum(y_true * y_pred, axis=(1, 2, 3))
    union = np.sum(y_true, axis=(1, 2, 3)) + np.sum(y_pred, axis=(1, 2, 3))
    dice = (2.0 * intersection) / (union + 1e-7)  # Adding a small epsilon to avoid division by zero
    return dice

print('-'*30)
print(f'Prediction Made Using Weights From Model: {model}')
print('-'*30)

pred_img_idx = 3
print('Testing Image Input Shape: ',(np.reshape(testing_scans_processed[pred_img_idx], (1,512,512,1))).shape)

best_model = load_model(model)
prediction = best_model.predict(np.reshape(testing_scans_processed[pred_img_idx], (1,512,512,1)))
# print('Testing Image Input Shape: ',testing_scans_processed[pred_img_idx].shape)
print('Prediction Mask Shape: ', prediction.shape)
print('\n')

DSC = dice_coefficient((np.reshape(testing_scans_processed[pred_img_idx], (1,512,512,1))), prediction)
print('Dice Similarity Coefficient (DSC) Metric Value: ', DSC)
print('\n')

fig, ax = plt.subplots()
ax.imshow(prediction[0, :, :, 0], cmap='gray')
ax.axis('on')
plt.title('Raw Segmentation Result')
plt.show()

fig, ax = plt.subplots()
ax.imshow(testing_scans_processed[pred_img_idx, :, :, 0], cmap='gray')
ax.axis('on')
plt.title('Raw Test Scan')
plt.show()

fig, ax = plt.subplots()
superimposed_image = superimpose_images(testing_scans_processed[pred_img_idx, :, :, 0], prediction[0, :, :, 0])
ax.imshow(superimposed_image, cmap='gray')
ax.axis('on')
plt.title('Superimposed Raw Test Scan & Prediction Mask')
plt.show()

# %%
# Dice Coefficient Loss Function
def dice_loss(y_true, y_pred):
    smooth = 1e-5  # Adding a small constant to avoid division by zero
    print(y_true.shape)
    print(y_pred.shape)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    print(intersection)
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3])
    dice_coefficient = (2.0 * intersection + smooth) / (union + smooth)
    loss = 1.0 - tf.reduce_mean(dice_coefficient)
    return loss

# %%
# Flatten the array to 2D
flattened_array = imgs_train.reshape((imgs_train.shape[0], -1))

# Write the array to the text file
# np.savetxt('D:/P4P Model Data/txt/DataCompiled', flattened_array)

# %%
flattened_array.shape
# Out:
# (2134, 262144)

# %%
def dice_coefficient(y_true, y_pred):
    intersection = np.sum(y_true * y_pred, axis=(1, 2, 3))
    union = np.sum(y_true, axis=(1, 2, 3)) + np.sum(y_pred, axis=(1, 2, 3))
    dice = (2.0 * intersection) / (union + 1e-7)  # Adding a small epsilon to avoid division by zero
    return dice

def assd(y_true, y_pred, spacing):
    surface_distances = surface_distance(y_true, y_pred, spacing)
    avg_surface_distance = np.mean(surface_distances)
    return avg_surface_distance

def surface_distance(y_true, y_pred, spacing):
    true_surface = find_surface_points(y_true, spacing)
    pred_surface = find_surface_points(y_pred, spacing)
    
    if true_surface.shape[0] == 0 or pred_surface.shape[0] == 0:
        raise ValueError("One or both surface point arrays are empty.")
    
    try:
        surface_distances_true_to_pred = directed_hausdorff(true_surface, pred_surface)[0]
        surface_distances_pred_to_true = directed_hausdorff(pred_surface, true_surface)[0]
        surface_distances = np.concatenate([surface_distances_true_to_pred, surface_distances_pred_to_true])
    except ValueError as e:
        print("Error occurred during Hausdorff distance calculation:", e)
        raise
    
    return surface_distances

def find_surface_points(mask, spacing):
    mask_padded = np.pad(mask, 1, mode='constant')
    mask_padded_diff = np.diff(mask_padded.astype(int), axis=0)
    
    surface_points = []
    for z in range(mask_padded_diff.shape[0]):
        surface_indices = np.where(mask_padded_diff[z] != 0)
        if len(surface_indices[0]) > 0:
            surface_points.extend(list(zip(surface_indices[0], surface_indices[1])))
    
    surface_points = np.array(surface_points)
    surface_points_phys = surface_points * spacing
    
    return surface_points_phys

def volume_error(y_true, y_pred):
    true_volume = np.sum(y_true)
    pred_volume = np.sum(y_pred)
    volume_error = np.abs(true_volume - pred_volume) / true_volume
    return volume_error


DSC = dice_coefficient(testing_masks_processed, prediction)
print('Dice Similarity Coefficient (DSC) Metric Value: ', DSC)
print('\n')

# VError = volume_error(testing_masks_processed, prediction)
# print('Volume Error (VError) Metric Value: ', VError)
# print('\n')

# spacing = 1
# ASSD = assd(testing_masks_processed, prediction, spacing)
# print('Average Symmetric Surface Distance (ASSD) Metric Value: ', ASSD)
# print('\n')
# Out:
# Dice Similarity Coefficient (DSC) Metric Value:  [4.0989216e-06]

# %%
# from keras.models import Model
# from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Concatenate, BatchNormalization, Activation, Conv2DTranspose, concatenate
# from keras.layers.core import Dropout
# import tensorflow as tf
# # from tensorflow.keras.models import Model
# from keras.layers import *
# from keras.optimizers import Adam
# from sklearn.model_selection import train_test_split
# import numpy as np

# # Define U-Net model
# def unet_model(input_shape):
#     inputs = Input(input_shape)
    
#     # Encoder
#     conv1 = Conv2D(64, 3, activation='relu', padding='same')(inputs)
#     conv1 = Conv2D(64, 3, activation='relu', padding='same')(conv1)
#     pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    
#     conv2 = Conv2D(128, 3, activation='relu', padding='same')(pool1)
#     conv2 = Conv2D(128, 3, activation='relu', padding='same')(conv2)
#     pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    
#     conv3 = Conv2D(256, 3, activation='relu', padding='same')(pool2)
#     conv3 = Conv2D(256, 3, activation='relu', padding='same')(conv3)
#     pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    
#     conv4 = Conv2D(512, 3, activation='relu', padding='same')(pool3)
#     conv4 = Conv2D(512, 3, activation='relu', padding='same')(conv4)
#     drop4 = Dropout(0.5)(conv4)
#     pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)
    
#     # Bottleneck
#     conv5 = Conv2D(1024, 3, activation='relu', padding='same')(pool4)
#     conv5 = Conv2D(1024, 3, activation='relu', padding='same')(conv5)
#     drop5 = Dropout(0.5)(conv5)
    
#     # Decoder
#     up6 = Conv2D(512, 2, activation='relu', padding='same')(UpSampling2D(size=(2, 2))(drop5))
#     merge6 = concatenate([drop4, up6], axis=3)
#     conv6 = Conv2D(512, 3, activation='relu', padding='same')(merge6)
#     conv6 = Conv2D(512, 3, activation='relu', padding='same')(conv6)
    
#     up7 = Conv2D(256, 2, activation='relu', padding='same')(UpSampling2D(size=(2, 2))(conv6))
#     merge7 = concatenate([conv3, up7], axis=3)
#     conv7 = Conv2D(256, 3, activation='relu', padding='same')(merge7)
#     conv7 = Conv2D(256, 3, activation='relu', padding='same')(conv7)
    
#     up8 = Conv2D(128, 2, activation='relu', padding='same')(UpSampling2D(size=(2, 2))(conv7))
#     merge8 = concatenate([conv2, up8], axis=3)
#     conv8 = Conv2D(128, 3, activation='relu', padding='same')(merge8)
#     conv8 = Conv2D(128, 3, activation='relu', padding='same')(conv8)
    
#     up9 = Conv2D(64, 2, activation='relu', padding='same')(UpSampling2D(size=(2, 2))(conv8))
#     merge9 = concatenate([conv1, up9], axis=3)
#     conv9 = Conv2D(64, 3, activation='relu', padding='same')(merge9)
#     conv9 = Conv2D(64, 3, activation='relu', padding='same')(conv9)
    
#     outputs = Conv2D(1, 1, activation='sigmoid')(conv9)
    
#     model = Model(inputs=inputs, outputs=outputs)
    
#     return model

# # Dice Coefficient Loss Function 
# def dice_coefficient(y_true, y_pred):
#     smooth = 1e-5
#     intersection = tf.reduce_sum(y_true * y_pred)
#     union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
#     dice = (2.0 * intersection + smooth) / (union + smooth)
#     return 1.0 - dice


# # Reformat image data structure
# training_scans_reshaped = np.concatenate(preprocessed_images, axis=0)
# training_scans = training_scans_reshaped.reshape((-1, 512, 512, 1))
# train_mask_tibia_labels_reshaped = np.concatenate(preprocessed_masks, axis=0)
# train_mask_tibia_labels = train_mask_tibia_labels_reshaped.reshape((-1, 512, 512, 1))

# # Split the data into training and validation sets\
# images_train, images_val, labels_train, labels_val = train_test_split(training_scans, train_mask_tibia_labels, test_size=0.2, random_state=0)
# unseen_scan_model = np.array(training_scans[2][100])
# images_train = images_train.astype('float32') / 255.0
# images_val = images_val.astype('float32') / 255.0

# print(images_train.shape)
# print(labels_train.shape)
# print(images_train.dtype)
# print(labels_train.dtype)
# print(images_val.shape)
# print(labels_val.shape)
# print(images_val.dtype)
# print(labels_val.dtype)
# print(unseen_scan_model.shape)

# # Expand dimensions for the channel (grayscale) dimension
# # images_train = np.expand_dims(images_train, axis=-1)
# # images_val = np.expand_dims(images_val, axis=-1)
# # labels_train = np.expand_dims(labels_train, axis=-1)
# # labels_val = np.expand_dims(labels_val, axis=-1)

# # Create an instance of the U-Net model
# input_shape = (512, 512, 1)  # For grayscale images

# # Create an instance of the U-Net model
# model = unet_model(input_shape)

# # Compile the model
# # Binary Cross Entropy Loss Function
# model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# # Dice Coefficient Loss Function
# # model.compile(optimizer=Adam(), loss=dice_coefficient, metrics=['accuracy'])

# # Train the model
# # Hyperparameter tuning -> batch_size
# model.fit(x=images_train, y=labels_train, batch_size=32, epochs=1, validation_data=(images_val, labels_val))
# # Evaluate the model
# loss, accuracy = model.evaluate(x=images_val, y=labels_val)

# # Perform inference on new, unseen MRI scans
# predictions = model.predict(unseen_scan_model)
